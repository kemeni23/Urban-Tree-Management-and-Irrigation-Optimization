# %% [markdown]
# # Importing libraries and reading in the datasets

# %%
import pandas as pd
from shapely.wkt import loads
from pyproj import Transformer
import folium
from pykml import parser
from pyproj import proj
import glob

# %%
pip install shapely
# Out:
# Requirement already satisfied: shapely in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: numpy>=1.14 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from shapely) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pykml
# Out:
# Requirement already satisfied: pykml in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (0.2.0)
# Requirement already satisfied: lxml>=3.3.6 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from pykml) (4.9.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (0.14.0)
# Requirement already satisfied: numpy in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from folium) (1.23.5)
# Requirement already satisfied: branca>=0.6.0 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from folium) (3.1.2)
# Requirement already satisfied: requests in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from folium) (2.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from requests->folium) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyproj
# Out:
# Requirement already satisfied: pyproj in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: certifi in /Users/dominikaumann/anaconda3/lib/python3.10/site-packages (from pyproj) (2022.12.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
df_newtrees = pd.read_csv('Datasets/newtrees.csv')
df_treescut = pd.read_csv('Datasets/tree_cutting_S-2018.csv', sep=';')
#df_Grundwassermessstellen = pd.read_csv('Datasets/Lage_der_Grundwassermessstellen_0.csv', sep=';')
#df_Wetterstation_City = pd.read_csv('Datasets/Wetterstation_City.csv')
#df_Wetterstation_Uni = pd.read_csv('Datasets/Wetterstation_Universitaet.csv')
# Out:
#     Kate-gorie  Ord-nung                     botanischer Name   \
# 0             2         3  Acer buergerianum syn. A. trifidum
# 1             1         2                      Acer campestre
# 2             1         2            Acer campestre „Elsrijk“
# 3             2         3         Acer campestre „Fastigiata“
# 4             2         2       Acer campestre „Green Column“
# ..          ...       ...                                  ...
# 338           A         1                          Ulmus minor
# 339           A         3                 Ulmus minor „Wredei“
# 340           A         2                         Ulmus pumila
# 341           A         1          Tilia platyphyllos „Örebro“
# 342           A         1           Tilia platyphyllos „Rubra“
#
#                     deutscher Name  Eignung als Bienen-weide   \
# 0                  Dreizahn- Ahorn                         –
# 1                        Feldahorn                          7
# 2                        Feld-Ahorn                         7
# 3    Feld-Ahorn - hecken-ahorn - ma                         7
# 4        Schmalkroni-ger Feldahorn                          7
# ..                              ...                       ...
# 338                       Feld-Ulme                         5
# 339                       Gold-Ulme                         5
# 340                 Sibirische Ulme                         –
# 341                     Sommerlinde                         6
# 342        Korallenrote Sommerlinde                         6
#
#                  Herkunft  Wuchs-höhe in Meter  Licht-durchläs-sigkeit   \
# 0                Ostasien                8 – 10                 mittel
# 1                heimisch               10 – 15                 mittel
# 2    heimisch, Zucht-form                6 – 12                 mittel
# 3    heimisch, Zucht-form                8 – 10                 mittel
# 4    heimisch, Zucht-form               10 – 12                 mittel
# ..                     ...                  ...                     ...
# 338              heimisch                   NaN                     NaN
# 339  heimisch, Zucht-form                   NaN                     NaN
# 340               Sibirien                   20                  gering
# 341   heimisch, Zucht-form                   30                  gering
# 342  heimisch, Zucht-form                    35                 gering
#
#                  Lichtbedarf  Winter-härte-zone  KLAM-Stadt   \
# 0    Sonne bis Halbschat-ten                  6b         2.1
# 1    Sonne bis Halbschat-ten                  5a         1.1
# 2    Sonne bis Halbschat-ten                  5a         1.1
# 3    Sonne bis Halbschat-ten                  5a         1.1
# 4    Sonne bis Halbschat-ten                  5a         1.1
# ..                        ...                ...         ...
# 338   Sonne bis Halbschat-ten                  5           -
# 339   Sonne bis Halbschat-ten                  –           -
# 340                     Sonne                  3           -
# 341   Sonne bis Halbschat-ten                  4         3.2
# 342   Sonne bis Halbschat-ten                  4         3.2
#
#                                           Bemerkungen
# 0    aufrechter Wuchs, locker verzweigte Äste, auf ...
# 1    eiförmige, unregelmäßige, im Alter mehr rundli...
# 2    wie die Art, jedoch gerader durchgehender Stam...
# 3                           gilt als mehltauresistenz
# 4    sehr hitzeverträglich, extrem windfest, schmal...
# ..                                                 ...
# 338  hochgewölbte, dichte Krone und meist kurzem St...
# 339  sehr schlank, robust gegen typische Ulmenerkra...
# 340          gewölbte Krone, Zweige behaart oder kahl
# 341  Wuchsform ist schmal, pyramidenförmig, später ...
# 342  wie die Art, jedoch regelmäßigere breit kegelf...
#
# [343 rows x 12 columns]

# %% [markdown]
# # Converting the geodata in df_newtrees

# %%
# Create the ETRS89 and WGS84 projections
etrs89 = proj.CRS.from_epsg(25832)
wgs84 = proj.CRS.from_epsg(4326)

# Create the Transformer to convert ETRS89 coordinates to WGS84 (latitude and longitude)
transformer = proj.Transformer.from_crs(etrs89, wgs84, always_xy=True)

# Extract geolocation data from the "geometry" column and convert to latitude and longitude
def convert_coordinates(geom):
    easting, northing = map(float, geom.strip('POINT ()').split())
    longitude, latitude = transformer.transform(easting, northing)
    return latitude, longitude

df_newtrees['latitude'], df_newtrees['longitude'] = zip(*df_newtrees['_geometry'].apply(convert_coordinates))

# %%
df_newtrees
# Out:
#                                                 FID     saison  \
# 0    stadtbaum.5747bea4-3b38-4b18-8e51-80adf4507d7f  2019/2020
# 1    stadtbaum.f008ca3c-82d6-4218-b60f-dce5419f037a  2019/2020
# 2    stadtbaum.4ce92e06-a0dc-4cb0-a0c9-a8baa707277a  2019/2020
# 3    stadtbaum.43e5741c-4a9d-4944-9a32-a624e059dc87  2019/2020
# 4    stadtbaum.0b9841a3-e503-4432-a765-d419cd290b6d  2019/2020
# ..                                              ...        ...
# 384  stadtbaum.1037bb4d-7b0a-45a2-858e-300f6efef64f  2021/2022
# 385  stadtbaum.d3210794-1375-4ce7-9c44-6c69b3eec361  2021/2022
# 386  stadtbaum.7b1d5cc9-b74b-42d3-aec4-02a791b8d1d0  2021/2022
# 387  stadtbaum.73457b9d-54f6-4a9e-9e83-a19d7486c084  2021/2022
# 388  stadtbaum.123c0bd5-250e-4313-998c-e8e972039303  2021/2022
#
#                  baumart                                               link  \
# 0               Magnolie  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 1              Hainbuche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 2              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 3              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 4              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# ..                   ...                                                ...
# 384            Hainbuche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 385          Zierkirsche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 386          Zierkirsche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 387  Kugel-Trompetenbaum  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 388            Mehlbeere  https://www.duesseldorf.de/stadtgruen/baeume-i...
#
#     last_update               _geometry   latitude  longitude
# 0    2022-08-09  POINT (345902 5678253)  51.234817   6.792643
# 1    2022-08-09  POINT (344779 5678180)  51.233857   6.776602
# 2    2022-08-09  POINT (345457 5678197)  51.234194   6.786298
# 3    2022-08-09  POINT (345457 5678232)  51.234508   6.786283
# 4    2022-08-09  POINT (345457 5678257)  51.234733   6.786272
# ..          ...                     ...        ...        ...
# 384  2022-08-09  POINT (353311 5666163)  51.128127   6.903630
# 385  2022-08-09  POINT (353632 5666255)  51.129036   6.908177
# 386  2022-08-09  POINT (353646 5666258)  51.129067   6.908376
# 387  2022-08-09  POINT (353192 5666289)  51.129229   6.901879
# 388  2022-08-09  POINT (352991 5668380)  51.147968   6.898155
#
# [389 rows x 8 columns]

# %% [markdown]
# # Dataset of the trees that were cut recently; Cleaning dataset

# %%
df_treescut
# Out:
#       Latitude  Longitude  Altitude Geometry               Grund der Fällung  \
# 0    51.225187   6.772675         0    point                     abgestorben
# 1    51.225252   6.790152         0    point                             NaN
# 2    51.219879   6.778963         0    point                             NaN
# 3    51.215577   6.770085         0    point                             NaN
# 4    51.226350   6.786974         0    point                             NaN
# ..         ...        ...       ...      ...                             ...
# 504  51.239493   6.803512         0    point  Morschungen im Stammfußbereich
# 505  51.239493   6.803512         0    point       Kernfäule im Kronenansatz
# 506  51.239493   6.803512         0    point  Morschungen im Stammfußbereich
# 507  51.239493   6.803512         0    point  Morschungen im Stammfußbereich
# 508  51.239493   6.803512         0    point  Morschungen im Stammfußbereich
#
#      Baum_ID   Gattung            Art          Sorte   Deutsch  \
# 0     1032.0   Robinia   pseudoacacia     Monophylla   Robinie
# 1     1591.0   Robinia   pseudoacacia     Monophylla   Robinie
# 2     2190.0  Aesculus  Hippocastanum            NaN  Kastanie
# 3     2326.0  Platanus     acerifolia            NaN   Platane
# 4     2412.0   Robinia   pseudoacacia  Umbraculifera   Robinie
# ..       ...       ...            ...            ...       ...
# 504      NaN   Populus        *hybrid            NaN    Pappel
# 505      NaN   Populus        *hybrid            NaN    Pappel
# 506      NaN   Populus        *hybrid            NaN    Pappel
# 507      NaN   Populus        *hybrid            NaN    Pappel
# 508      NaN   Populus        *hybrid            NaN    Pappel
#
#                  Straße      Hausnummer  Pflegebezirk  Politischer Bezirk  \
# 0        Flinger Straße  li. Von. Nr. 6        3201.0                 1.0
# 1    Hohenzollernstraße              24           NaN                 NaN
# 2           Königsallee             NaN           NaN                 NaN
# 3       Konkordiastraße          Schule           NaN                 NaN
# 4       Liesegangstraße          ggü 11           NaN                 NaN
# ..                  ...             ...           ...                 ...
# 504             Zoopark             NaN        3104.0                 2.0
# 505             Zoopark             NaN        3104.0                 2.0
# 506             Zoopark             NaN        3104.0                 2.0
# 507             Zoopark             NaN        3104.0                 2.0
# 508             Zoopark             NaN        3104.0                 2.0
#
#      Stammumfang      X_Koord     Y_Koord
# 0            NaN  32344475.67  5677224.22
# 1            NaN  32345696.08  5677194.67
# 2            NaN  32344896.81  5676620.84
# 3            NaN  32344262.40  5676161.23
# 4            NaN  32345477.85  5677323.39
# ..           ...          ...         ...
# 504        147.0  32346676.20  5678750.10
# 505        334.0  32346676.20  5678750.10
# 506        337.0  32346676.20  5678750.10
# 507        342.0  32346676.20  5678750.10
# 508        350.0  32346676.20  5678750.10
#
# [509 rows x 17 columns]

# %%
# In df_treescut: Define a mapping of old reasons for cutting to new values (renaming)
reasons_mapping = {
    'Morschungen im Stammfußbereich': 'Morschungen',
    'Morschungen am Stammfuß': 'Morschungen',  # Example of a different name for the same reason
    'Morschungen am STammbereich': 'Morschungen',
    'Morschung im Stammbereich': 'Morschungen',  
    'Morschungen am Stammbereich': 'Morschungen',
    'Morschungen am Stammfußbereich': 'Morschungen',
    'Morschungen im Stammbereich': 'Morschungen',
    'Morschung': 'Morschungen',
    'Morschungen. Krone ausgebrochen': 'Morschungen',
    'Morschungen am Kronenansatz': 'Morschungen',
    'Morschungen im Kronenansatz': 'Morschungen',
    'Pilzbefall (Lackporling)': 'Disease',
    'Pilzbefall (Lackporling) ': 'Disease',
    'Pilzbefall (Schwefelporling)': 'Disease',
    'Pilzbefall (Schillerporling)': 'Disease',
    'Pilzbefall (Schillerporling) ': 'Disease',
    'Pilzbefall (Riesenporling)': 'Disease',
    'Pilzbefall (Zunderschwamm)': 'Disease',
    'Pilzbefall (Hallimasch)': 'Disease',
    'Pilzbefall (zottiger Schillerporling)': 'Disease',
    'Pilzbefall (schuppiger Porling)': 'Disease',
    'Pilzbefall (sparriger Schüppling)': 'Disease',
    'Pilzbefall am Wurzelhals (Schillerporling)': 'Disease',
    'Pilzbefall am Wurzelhals (Lackporling)': 'Disease',
    'Pilzbefall am Wurzelhals': 'Disease',
    'Pilzbefall': 'Disease',
    'Komplexerkrankung': 'Disease',
    'Rußrindenkrankheit': 'Disease',
    'Riss im Zwiesel': 'Riss im Zwieselbereich',
    'Sturmschaden ': 'Sturmschaden',
    'Hochspannungsleitung Spannungsüberschlag': 'Unfallschaden',
    'Wurzelfäule': 'Wurzelschäden',
    'Neubaumaßnahme ': 'Baumaßnahme',
    'Zwiesel am Stammfuß': 'Stammschäden',
    'Riss im Zwieselbereich': 'Stammschäden',
    'Hohlstellen am Stammfuß': 'Stammschäden',
    'Vandalismus Verursacher unbekannt': 'Vandalismus',
    'nur noch Stamm': 'Torso',
    'Sturmschaden': 'Sturm-, Gebäude- und Unfallschäden',
    'Gebäudeschäden': 'Sturm-, Gebäude- und Unfallschäden',
    'Unfallschaden': 'Sturm-, Gebäude- und Unfallschäden',
    'Sturm- und Gebäudeschäden': 'Sturm-, Gebäude- und Unfallschäden',
    'abgestorben': 'dead',
    'Sturm-, Gebäude- und Unfallschäden': 'Storm, building and accident damage',
    'Stammschäden': 'Trunk damage',
    'Riss im Zwieselbereich':'Crack in the Zwiesel area',
    'Wurzelschäden': 'Root damage',
    'Unfallgefahr': 'Risk of accident',
    'Vandalismus': 'Vandalism',
    'Unfallschaden': 'Storm, building and accident damage',
    'Baumaßnahme': 'Construction measure',
    'Sturmschaden': 'Storm, building and accident damage',
    'Kernfäule im Kronenansatz': 'Core rot in the crown base'
}

# Replace the values in the "Grund der Fällung" column using the mapping
df_treescut['Grund der Fällung'] = df_treescut['Grund der Fällung'].replace(reasons_mapping)

# Get the unique values in the "Grund der Fällung" column after renaming
unique_reasons = df_treescut['Grund der Fällung'].unique()

# Print the unique reasons for cutting after renaming
print(unique_reasons)
# Out:
# ['dead' nan 'Torso' 'Morschungen' 'Storm, building and accident damage'
#  'Disease' 'Stammschäden' 'Trunk damage' 'Riss im Zwieselbereich'
#  'Wurzelschäden' 'Sturm-, Gebäude- und Unfallschäden' 'Risk of accident'
#  'Crack in the Zwiesel area' 'Vandalismus' 'Unfallschaden'
#  'Construction measure' 'Sturmschaden' 'Baumaßnahme' 'Root damage'
#  'Core rot in the crown base']

# %%
#Creating a map object and setting the initial view with the latitude and longitude of Düsseldorf
duesseldorf_coords = (51.2277, 6.7735)
map_tree_location = folium.Map(location=duesseldorf_coords, tiles="cartodb positron", zoom_start=12)

#Creating a second map object and setting the initial view with the latitude and longitude of Düsseldorf
map_tree_location2 = folium.Map(location=duesseldorf_coords, tiles="cartodb positron", zoom_start=12)

# %%
#Iterating through df_newtrees containing the tree locations and tree type, and add markers for each tree location to the map
for index, row in df_newtrees.iterrows():
    tree_coords1 = (row['latitude'], row['longitude'])
    popup_content1 = f"Tree Type: {row['baumart']}, Planting Year: {row['saison']}"
    marker1 = folium.Marker(location=tree_coords1, popup=popup_content1, icon=folium.Icon(color='green', icon='leaf')) 
    marker1.add_to(map_tree_location)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 3
#       1 #Iterating through df_newtrees containing the tree locations and tree type, and add markers for each tree location to the map
#       2 for index, row in df_newtrees.iterrows():
# ----> 3     tree_coords1 = (row['latitude'], row['longitude'])
#       4     popup_content1 = f"Tree Type: {row['baumart']}, Planting Year: {row['saison']}"
#       5     marker1 = folium.Marker(location=tree_coords1, popup=popup_content1, icon=folium.Icon(color='green', icon='leaf'))
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'latitude'

# %%
#Iterating through df_newtrees containing the tree locations and tree type, and add markers for each tree location to the second map
for index, row in df_newtrees.iterrows():
    tree_coords1 = (row['latitude'], row['longitude'])
    popup_content1 = f"Tree Type: {row['baumart']}, Planting Year: {row['saison']}"
    marker1 = folium.Marker(location=tree_coords1, popup=popup_content1, icon=folium.Icon(color='green', icon='leaf')) 
    marker1.add_to(map_tree_location2)
    
    #Iterating through df_treescut containing the tree locations and tree type, and add markers for each tree location to the second map
for index, row in df_treescut.iterrows():
    tree_coords2 = (row['Latitude'], row['Longitude'])
    popup_content2 = f"Tree Type: {row['Deutsch']}, Reason for cutting: {row['Grund der Fällung']}"
    marker2 = folium.Marker(location=tree_coords2, popup=popup_content2,  icon=folium.Icon(color='red', icon='leaf')) 
    marker2.add_to(map_tree_location2)

# %%
#Save the map as an HTML file or display it directly in a Jupyter Notebook
map_tree_location.save('new_trees_map.html')

#Save the second map as an HTML file or display it directly in a Jupyter Notebook
map_tree_location2.save('new_and_cutted_trees_map.html')

# %%
map_tree_location
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37f959ecafb7a4e331984e09379a8100 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37f959ecafb7a4e331984e09379a8100&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37f959ecafb7a4e331984e09379a8100 = L.map(
#                 &quot;map_37f959ecafb7a4e331984e09379a8100&quot;,
#                 {
#                     center: [51.2277, 6.7735],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72e345640b79483db1288bebfc00de39 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_37f959ecafb7a4e331984e09379a8100);
#
#
#             var marker_c00465b5b741e105566446e1a0b8c47d = L.marker(
#                 [51.23481742305189, 6.792643441231207],
#                 {}
#             ).addTo(map_37f959ecafb7a4e331984e09379a8100);
#
#
#             var icon_d6982e6f94e48c1e263cbdbad57bb777 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c00465b5b741e105566446e1a0b8c47d.setIcon(icon_d6982e6f94e48c1e263cbdbad57bb777);
#
#
#         var popup_078004156eacc6a20cc383e894c5ec88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_34b09358a1117fb1101252747aa18868 = $(`&lt;div id=&quot;html_34b09358a1117fb1101252747aa18868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tree Type: Magnolie, Planting Year: 2019/2020&lt;/div&gt;`)[0];
#                 popup_078004156eacc6a20cc383e894c5ec88.setContent(html_34b09358a1117fb1101252747aa18868);
#
#
#
#         marker_c00465b5b741e105566446e1a0b8c47d.bindPopup(popup_078004156eacc6a20cc383e894c5ec88)
#         ;
#
#
#
#
#             var marker_71ca62ae2bc8a354bab2a17aa5ed348c = L.marker(
#                 [51.233857122992625, 6.776601749010137],
#                 {}
#             ).addTo(map_37f959ecafb7a4e331984e09379a8100);
#
#
#             var icon_0bc7e5682cc90ff3acc0d19a8102968b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_71ca62ae2bc8a354bab2a17aa5ed348c.setIcon(icon_0bc7e5682cc90ff3acc0d19a8102968b);
#
#
#         var popup_0a2b943b34a686b89c77710d9b2f719a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ff23a359f83d09408d69907100af7a71 = $(`&lt;div id=&quot;html_ff23a359f83d09408d69907100af7a71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tree Type: Hainbuche, Planting Year: 2019/2020&lt;/div&gt;`)[0];
#                 popup_0a2b943b34a686b89c77710d9b2f719a.setContent(html_ff23a359f83d09408d69907100af7a71);
#
#
#
#         marker_71ca62ae2bc8a354bab2a17aa5ed348c.bindPopup(popup_0a2b943b34a686b89c77710d9b2f719a)
#         ;
#
#
#
#
#             var marker_2354400988a459e7d7371f5354395fbb = L.marker(
#                 [51.23419389426508, 6.78629835106173],
#                 {}
#             ).addTo(map_37f959ecafb7a4e331984e09379a8100);
#
#
#             var icon_7e65093ff9ff2dfa0dcd50989e6dbf46 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2354400988a459e7d7371f5354395fbb.setIcon(icon_7e65093ff9ff2dfa0dcd50989e6dbf46);
#
#
#         var popup_34756adb21303bd9e10fd64c1d038a6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d2af1c9c24f27653791e1ba38e48bb7 = $(`&lt;div id=&quot;html_5d2af1c9c24f27653791e1ba38e48bb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tree Type: Zierapfel, Planting Year: 2019/2020&lt;/div&gt;`)[0];
#                 popup_34756adb21303bd9e10fd64c1d038a6a.setContent(html_5d2af1c9c24f27653791e1ba38e48bb7);
#
#
#
#         marker_2354400988a459e7d7371f5354395fbb.bindPopup(popup_34756adb21303bd9e10fd64c1d038a6a)
#         ;
#
#
#
#
#             var marker_ac46694e0648a670feee852a8649269f = L.marker(

# %%
map_tree_location2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef1de9ef8457a05816d96a3f00b53efd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef1de9ef8457a05816d96a3f00b53efd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef1de9ef8457a05816d96a3f00b53efd = L.map(
#                 &quot;map_ef1de9ef8457a05816d96a3f00b53efd&quot;,
#                 {
#                     center: [51.2277, 6.7735],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c20d04546800241a3bf624d4114b50c = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef1de9ef8457a05816d96a3f00b53efd);
#
#
#             var marker_ecb726c31b8869aee682cee62f1443f9 = L.marker(
#                 [51.23481742305189, 6.792643441231207],
#                 {}
#             ).addTo(map_ef1de9ef8457a05816d96a3f00b53efd);
#
#
#             var icon_28c4a7fb8db71d33a2df4fa83aef50b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ecb726c31b8869aee682cee62f1443f9.setIcon(icon_28c4a7fb8db71d33a2df4fa83aef50b3);
#
#
#         var popup_26648f03df91eed4e0acf74f05445bc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_894f932c744409caade7a21f0320ca63 = $(`&lt;div id=&quot;html_894f932c744409caade7a21f0320ca63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tree Type: Magnolie, Planting Year: 2019/2020&lt;/div&gt;`)[0];
#                 popup_26648f03df91eed4e0acf74f05445bc0.setContent(html_894f932c744409caade7a21f0320ca63);
#
#
#
#         marker_ecb726c31b8869aee682cee62f1443f9.bindPopup(popup_26648f03df91eed4e0acf74f05445bc0)
#         ;
#
#
#
#
#             var marker_dc57f65c0e103fe74a123a20fbcb1a77 = L.marker(
#                 [51.233857122992625, 6.776601749010137],
#                 {}
#             ).addTo(map_ef1de9ef8457a05816d96a3f00b53efd);
#
#
#             var icon_afe0bcf33b39cb14b05296722fb9d24f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dc57f65c0e103fe74a123a20fbcb1a77.setIcon(icon_afe0bcf33b39cb14b05296722fb9d24f);
#
#
#         var popup_b93c048bfdced070238739aefc326276 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb7ecfe32538fc0cae74549136444afa = $(`&lt;div id=&quot;html_cb7ecfe32538fc0cae74549136444afa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tree Type: Hainbuche, Planting Year: 2019/2020&lt;/div&gt;`)[0];
#                 popup_b93c048bfdced070238739aefc326276.setContent(html_cb7ecfe32538fc0cae74549136444afa);
#
#
#
#         marker_dc57f65c0e103fe74a123a20fbcb1a77.bindPopup(popup_b93c048bfdced070238739aefc326276)
#         ;
#
#
#
#
#             var marker_7173c6ed29ef5aa1726700807b66c8af = L.marker(
#                 [51.23419389426508, 6.78629835106173],
#                 {}
#             ).addTo(map_ef1de9ef8457a05816d96a3f00b53efd);
#
#
#             var icon_a0f7ac0ef86b4f88cec0c1a89a28c172 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7173c6ed29ef5aa1726700807b66c8af.setIcon(icon_a0f7ac0ef86b4f88cec0c1a89a28c172);
#
#
#         var popup_38cf3d7e3b379a0b3ddf95d80a69bc18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ed4e397d62259c5af0c97c18f64b923 = $(`&lt;div id=&quot;html_1ed4e397d62259c5af0c97c18f64b923&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tree Type: Zierapfel, Planting Year: 2019/2020&lt;/div&gt;`)[0];
#                 popup_38cf3d7e3b379a0b3ddf95d80a69bc18.setContent(html_1ed4e397d62259c5af0c97c18f64b923);
#
#
#
#         marker_7173c6ed29ef5aa1726700807b66c8af.bindPopup(popup_38cf3d7e3b379a0b3ddf95d80a69bc18)
#         ;
#
#
#
#
#             var marker_58660a989e49738172d79fd52e7df763 = L.marker(

# %% [markdown]
# # Weather Data (Adding the coordinates)

# %%
# dropping the column "Unnamed: 0" in the weather datasets
df_Wetterstation_City = df_Wetterstation_City.drop(columns = "Unnamed: 0") 
df_Wetterstation_Uni = df_Wetterstation_Uni.drop(columns = "Unnamed: 0")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # dropping the column "Unnamed: 0" in the weather datasets
# ----> 2 df_Wetterstation_City = df_Wetterstation_City.drop(columns = "Unnamed: 0")
#       3 df_Wetterstation_Uni = df_Wetterstation_Uni.drop(columns = "Unnamed: 0")
#
# NameError: name 'df_Wetterstation_City' is not defined

# %%
### Adding the coordinates for the two weather stations

# Adding a new column "Latitude" to the two weather datasets
df_Wetterstation_City["Latitude"] = 51.24
df_Wetterstation_Uni["Latitude"] = 51.19

# Adding a new column "Longitude" to the two weather datasets
df_Wetterstation_City["Longitude"] = 6.79
df_Wetterstation_Uni["Longitude"] = 6.80

# %%
df_Wetterstation_City.head(100)

# %%
df_Wetterstation_Uni

# %% [markdown]
# # Combining the datasets df_Grundwassermessstellen and the csv files with the groundwater levels into one dataset: df_groundwater

# %%
# Define the pattern for the CSV files (e.g., all CSV files in the current directory)
csv_files_pattern = 'Datasets/Groundwater/*.csv'  # Update the path to your dataset directory

# Get a list of file paths that match the pattern using glob
csv_file_paths = glob.glob(csv_files_pattern)

# Create an empty list to store DataFrames after processing
processed_dataframes = []

# Loop through each file path
for file_path in csv_file_paths:
    # Read the CSV file into a DataFrame
    df = pd.read_csv(file_path, sep=';', encoding="cp1252")
    
    # Get the values from the first row for 'Latitude', 'Longitude', and 'Street'
    latitude_value = df.loc[0, 'Latitude']
    longitude_value = df.loc[0, 'Longitude']
    street_value = df.loc[0, 'Street']
    
    # Fill the corresponding columns with the extracted values
    df['Latitude'] = latitude_value
    df['Longitude'] = longitude_value
    df['Street'] = street_value
    
    # Append the processed DataFrame to the list
    processed_dataframes.append(df)

# Concatenate the processed DataFrames
df_groundwater = pd.concat(processed_dataframes, ignore_index=True)

# Dropping the column 'Unnamed: 5' (Don't know where that came from)
df_groundwater = df_groundwater.drop(columns=['Unnamed: 5'])

# Renaming the columns x, y
df_groundwater.rename(columns = {'x':'Date', 'y':'monthly_groundwater'}, inplace = True)

# %%
df_groundwater

# %% [markdown]
# # Code for integrating KLAM in Maps and tables

# %%
df_treescut
# Out:
#       Latitude  Longitude  Altitude Geometry           Grund der Fällung  \
# 0    51.225187   6.772675         0    point                        dead
# 1    51.225252   6.790152         0    point                         NaN
# 2    51.219879   6.778963         0    point                         NaN
# 3    51.215577   6.770085         0    point                         NaN
# 4    51.226350   6.786974         0    point                         NaN
# ..         ...        ...       ...      ...                         ...
# 504  51.239493   6.803512         0    point                 Morschungen
# 505  51.239493   6.803512         0    point  Core rot in the crown base
# 506  51.239493   6.803512         0    point                 Morschungen
# 507  51.239493   6.803512         0    point                 Morschungen
# 508  51.239493   6.803512         0    point                 Morschungen
#
#      Baum_ID   Gattung            Art          Sorte   Deutsch  \
# 0     1032.0   Robinia   pseudoacacia     Monophylla   Robinie
# 1     1591.0   Robinia   pseudoacacia     Monophylla   Robinie
# 2     2190.0  Aesculus  Hippocastanum            NaN  Kastanie
# 3     2326.0  Platanus     acerifolia            NaN   Platane
# 4     2412.0   Robinia   pseudoacacia  Umbraculifera   Robinie
# ..       ...       ...            ...            ...       ...
# 504      NaN   Populus        *hybrid            NaN    Pappel
# 505      NaN   Populus        *hybrid            NaN    Pappel
# 506      NaN   Populus        *hybrid            NaN    Pappel
# 507      NaN   Populus        *hybrid            NaN    Pappel
# 508      NaN   Populus        *hybrid            NaN    Pappel
#
#                  Straße      Hausnummer  Pflegebezirk  Politischer Bezirk  \
# 0        Flinger Straße  li. Von. Nr. 6        3201.0                 1.0
# 1    Hohenzollernstraße              24           NaN                 NaN
# 2           Königsallee             NaN           NaN                 NaN
# 3       Konkordiastraße          Schule           NaN                 NaN
# 4       Liesegangstraße          ggü 11           NaN                 NaN
# ..                  ...             ...           ...                 ...
# 504             Zoopark             NaN        3104.0                 2.0
# 505             Zoopark             NaN        3104.0                 2.0
# 506             Zoopark             NaN        3104.0                 2.0
# 507             Zoopark             NaN        3104.0                 2.0
# 508             Zoopark             NaN        3104.0                 2.0
#
#      Stammumfang      X_Koord     Y_Koord
# 0            NaN  32344475.67  5677224.22
# 1            NaN  32345696.08  5677194.67
# 2            NaN  32344896.81  5676620.84
# 3            NaN  32344262.40  5676161.23
# 4            NaN  32345477.85  5677323.39
# ..           ...          ...         ...
# 504        147.0  32346676.20  5678750.10
# 505        334.0  32346676.20  5678750.10
# 506        337.0  32346676.20  5678750.10
# 507        342.0  32346676.20  5678750.10
# 508        350.0  32346676.20  5678750.10
#
# [509 rows x 17 columns]

# %%
df_newtrees
# Out:
#                                                 FID     saison  \
# 0    stadtbaum.5747bea4-3b38-4b18-8e51-80adf4507d7f  2019/2020
# 1    stadtbaum.f008ca3c-82d6-4218-b60f-dce5419f037a  2019/2020
# 2    stadtbaum.4ce92e06-a0dc-4cb0-a0c9-a8baa707277a  2019/2020
# 3    stadtbaum.43e5741c-4a9d-4944-9a32-a624e059dc87  2019/2020
# 4    stadtbaum.0b9841a3-e503-4432-a765-d419cd290b6d  2019/2020
# ..                                              ...        ...
# 384  stadtbaum.1037bb4d-7b0a-45a2-858e-300f6efef64f  2021/2022
# 385  stadtbaum.d3210794-1375-4ce7-9c44-6c69b3eec361  2021/2022
# 386  stadtbaum.7b1d5cc9-b74b-42d3-aec4-02a791b8d1d0  2021/2022
# 387  stadtbaum.73457b9d-54f6-4a9e-9e83-a19d7486c084  2021/2022
# 388  stadtbaum.123c0bd5-250e-4313-998c-e8e972039303  2021/2022
#
#                  baumart                                               link  \
# 0               Magnolie  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 1              Hainbuche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 2              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 3              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 4              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# ..                   ...                                                ...
# 384            Hainbuche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 385          Zierkirsche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 386          Zierkirsche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 387  Kugel-Trompetenbaum  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 388            Mehlbeere  https://www.duesseldorf.de/stadtgruen/baeume-i...
#
#     last_update               _geometry   latitude  longitude
# 0    2022-08-09  POINT (345902 5678253)  51.234817   6.792643
# 1    2022-08-09  POINT (344779 5678180)  51.233857   6.776602
# 2    2022-08-09  POINT (345457 5678197)  51.234194   6.786298
# 3    2022-08-09  POINT (345457 5678232)  51.234508   6.786283
# 4    2022-08-09  POINT (345457 5678257)  51.234733   6.786272
# ..          ...                     ...        ...        ...
# 384  2022-08-09  POINT (353311 5666163)  51.128127   6.903630
# 385  2022-08-09  POINT (353632 5666255)  51.129036   6.908177
# 386  2022-08-09  POINT (353646 5666258)  51.129067   6.908376
# 387  2022-08-09  POINT (353192 5666289)  51.129229   6.901879
# 388  2022-08-09  POINT (352991 5668380)  51.147968   6.898155
#
# [389 rows x 8 columns]

# %%
df_klam = pd.read_csv('Datasets/klams2.csv', sep=';')

df_klam.rename(columns={'deutscher Name ': 'baumart'}, inplace=True)
df_treescut.rename(columns={'Deutsch': 'baumart'}, inplace=True)
df_klam
# Out:
#     Kate-gorie  Ord-nung                     botanischer Name   \
# 0             2         3  Acer buergerianum syn. A. trifidum
# 1             1         2                      Acer campestre
# 2             1         2            Acer campestre „Elsrijk“
# 3             2         3         Acer campestre „Fastigiata“
# 4             2         2       Acer campestre „Green Column“
# ..          ...       ...                                  ...
# 338           A         1                          Ulmus minor
# 339           A         3                 Ulmus minor „Wredei“
# 340           A         2                         Ulmus pumila
# 341           A         1          Tilia platyphyllos „Örebro“
# 342           A         1           Tilia platyphyllos „Rubra“
#
#                             baumart Eignung als Bienen-weide   \
# 0                  Dreizahn- Ahorn                         –
# 1                        Feldahorn                          7
# 2                        Feld-Ahorn                         7
# 3    Feld-Ahorn - hecken-ahorn - ma                         7
# 4        Schmalkroni-ger Feldahorn                          7
# ..                              ...                       ...
# 338                       Feld-Ulme                         5
# 339                       Gold-Ulme                         5
# 340                 Sibirische Ulme                         –
# 341                     Sommerlinde                         6
# 342        Korallenrote Sommerlinde                         6
#
#                  Herkunft  Wuchs-höhe in Meter  Licht-durchläs-sigkeit   \
# 0                Ostasien                8 – 10                 mittel
# 1                heimisch               10 – 15                 mittel
# 2    heimisch, Zucht-form                6 – 12                 mittel
# 3    heimisch, Zucht-form                8 – 10                 mittel
# 4    heimisch, Zucht-form               10 – 12                 mittel
# ..                     ...                  ...                     ...
# 338              heimisch                   NaN                     NaN
# 339  heimisch, Zucht-form                   NaN                     NaN
# 340               Sibirien                   20                  gering
# 341   heimisch, Zucht-form                   30                  gering
# 342  heimisch, Zucht-form                    35                 gering
#
#                  Lichtbedarf  Winter-härte-zone  KLAM-Stadt   \
# 0    Sonne bis Halbschat-ten                  6b         2.1
# 1    Sonne bis Halbschat-ten                  5a         1.1
# 2    Sonne bis Halbschat-ten                  5a         1.1
# 3    Sonne bis Halbschat-ten                  5a         1.1
# 4    Sonne bis Halbschat-ten                  5a         1.1
# ..                        ...                ...         ...
# 338   Sonne bis Halbschat-ten                  5           -
# 339   Sonne bis Halbschat-ten                  –           -
# 340                     Sonne                  3           -
# 341   Sonne bis Halbschat-ten                  4         3.2
# 342   Sonne bis Halbschat-ten                  4         3.2
#
#                                           Bemerkungen
# 0    aufrechter Wuchs, locker verzweigte Äste, auf ...
# 1    eiförmige, unregelmäßige, im Alter mehr rundli...
# 2    wie die Art, jedoch gerader durchgehender Stam...
# 3                           gilt als mehltauresistenz
# 4    sehr hitzeverträglich, extrem windfest, schmal...
# ..                                                 ...
# 338  hochgewölbte, dichte Krone und meist kurzem St...
# 339  sehr schlank, robust gegen typische Ulmenerkra...
# 340          gewölbte Krone, Zweige behaart oder kahl
# 341  Wuchsform ist schmal, pyramidenförmig, später ...
# 342  wie die Art, jedoch regelmäßigere breit kegelf...
#
# [343 rows x 12 columns]

# %%
# Sample source data
source_data = pd.DataFrame({
    'ID': [1, 2, 3, 4],
    'Value': ['A', 'B', 'C', 'D']
})

# Sample lookup table
lookup_table = pd.DataFrame({
    'ID': [2, 4],
    'Description': ['Description B', 'Description D']
})

# Perform VLOOKUP-like operation using pandas merge
merged_data = pd.merge(source_data, lookup_table, on='ID', how='left')

print(merged_data)
# Out:
#    ID Value    Description
# 0   1     A            NaN
# 1   2     B  Description B
# 2   3     C            NaN
# 3   4     D  Description D

# %%
df_newtrees_klam = pd.merge(df_newtrees,df_klam,on="baumart", how="left")
df_treescut_klam = pd.merge(df_treescut,df_klam,on="baumart", how="left")

# %%
df_treescut_klam
# Out:
#       Latitude  Longitude  Altitude Geometry               Grund der Fällung  \
# 0    51.225187   6.772675         0    point                     abgestorben
# 1    51.225252   6.790152         0    point                             NaN
# 2    51.219879   6.778963         0    point                             NaN
# 3    51.215577   6.770085         0    point                             NaN
# 4    51.226350   6.786974         0    point                             NaN
# ..         ...        ...       ...      ...                             ...
# 504  51.239493   6.803512         0    point  Morschungen im Stammfußbereich
# 505  51.239493   6.803512         0    point       Kernfäule im Kronenansatz
# 506  51.239493   6.803512         0    point  Morschungen im Stammfußbereich
# 507  51.239493   6.803512         0    point  Morschungen im Stammfußbereich
# 508  51.239493   6.803512         0    point  Morschungen im Stammfußbereich
#
#      Baum_ID   Gattung            Art          Sorte   baumart  \
# 0     1032.0   Robinia   pseudoacacia     Monophylla   Robinie
# 1     1591.0   Robinia   pseudoacacia     Monophylla   Robinie
# 2     2190.0  Aesculus  Hippocastanum            NaN  Kastanie
# 3     2326.0  Platanus     acerifolia            NaN   Platane
# 4     2412.0   Robinia   pseudoacacia  Umbraculifera   Robinie
# ..       ...       ...            ...            ...       ...
# 504      NaN   Populus        *hybrid            NaN    Pappel
# 505      NaN   Populus        *hybrid            NaN    Pappel
# 506      NaN   Populus        *hybrid            NaN    Pappel
# 507      NaN   Populus        *hybrid            NaN    Pappel
# 508      NaN   Populus        *hybrid            NaN    Pappel
#
#                  Straße      Hausnummer  Pflegebezirk  Politischer Bezirk  \
# 0        Flinger Straße  li. Von. Nr. 6        3201.0                 1.0
# 1    Hohenzollernstraße              24           NaN                 NaN
# 2           Königsallee             NaN           NaN                 NaN
# 3       Konkordiastraße          Schule           NaN                 NaN
# 4       Liesegangstraße          ggü 11           NaN                 NaN
# ..                  ...             ...           ...                 ...
# 504             Zoopark             NaN        3104.0                 2.0
# 505             Zoopark             NaN        3104.0                 2.0
# 506             Zoopark             NaN        3104.0                 2.0
# 507             Zoopark             NaN        3104.0                 2.0
# 508             Zoopark             NaN        3104.0                 2.0
#
#      Stammumfang      X_Koord     Y_Koord
# 0            NaN  32344475.67  5677224.22
# 1            NaN  32345696.08  5677194.67
# 2            NaN  32344896.81  5676620.84
# 3            NaN  32344262.40  5676161.23
# 4            NaN  32345477.85  5677323.39
# ..           ...          ...         ...
# 504        147.0  32346676.20  5678750.10
# 505        334.0  32346676.20  5678750.10
# 506        337.0  32346676.20  5678750.10
# 507        342.0  32346676.20  5678750.10
# 508        350.0  32346676.20  5678750.10
#
# [509 rows x 17 columns]

# %%
df_newtrees_klam
# Out:
#                                                 FID     saison  \
# 0    stadtbaum.5747bea4-3b38-4b18-8e51-80adf4507d7f  2019/2020
# 1    stadtbaum.f008ca3c-82d6-4218-b60f-dce5419f037a  2019/2020
# 2    stadtbaum.4ce92e06-a0dc-4cb0-a0c9-a8baa707277a  2019/2020
# 3    stadtbaum.43e5741c-4a9d-4944-9a32-a624e059dc87  2019/2020
# 4    stadtbaum.0b9841a3-e503-4432-a765-d419cd290b6d  2019/2020
# ..                                              ...        ...
# 557  stadtbaum.d3210794-1375-4ce7-9c44-6c69b3eec361  2021/2022
# 558  stadtbaum.7b1d5cc9-b74b-42d3-aec4-02a791b8d1d0  2021/2022
# 559  stadtbaum.7b1d5cc9-b74b-42d3-aec4-02a791b8d1d0  2021/2022
# 560  stadtbaum.73457b9d-54f6-4a9e-9e83-a19d7486c084  2021/2022
# 561  stadtbaum.123c0bd5-250e-4313-998c-e8e972039303  2021/2022
#
#                  baumart                                               link  \
# 0               Magnolie  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 1              Hainbuche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 2              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 3              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 4              Zierapfel  https://www.duesseldorf.de/stadtgruen/baeume-i...
# ..                   ...                                                ...
# 557          Zierkirsche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 558          Zierkirsche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 559          Zierkirsche  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 560  Kugel-Trompetenbaum  https://www.duesseldorf.de/stadtgruen/baeume-i...
# 561            Mehlbeere  https://www.duesseldorf.de/stadtgruen/baeume-i...
#
#     last_update               _geometry Kate-gorie  Ord-nung   \
# 0    2022-08-09  POINT (345902 5678253)           3         3
# 1    2022-08-09  POINT (344779 5678180)           1         2
# 2    2022-08-09  POINT (345457 5678197)           2         3
# 3    2022-08-09  POINT (345457 5678232)           2         3
# 4    2022-08-09  POINT (345457 5678257)           2         3
# ..          ...                     ...         ...       ...
# 557  2022-08-09  POINT (353632 5666255)           3         3
# 558  2022-08-09  POINT (353646 5666258)           1         3
# 559  2022-08-09  POINT (353646 5666258)           3         3
# 560  2022-08-09  POINT (353192 5666289)           2         3
# 561  2022-08-09  POINT (352991 5668380)           1         2
#
#                   botanischer Name  Eignung als Bienen-weide   \
# 0                Magnolia „Galaxy“                          3
# 1    Carpinus betulus „Fastigiata“                          3
# 2                 Malus „Evereste“                          7
# 3                 Malus „Evereste“                          7
# 4                 Malus „Evereste“                          7
# ..                              ...                       ...
# 557               Prunus „Pandora“                          6
# 558                     Cornus mas                          6
# 559               Prunus „Pandora“                          6
# 560           Catalpa bignonioides                          5
# 561        Sorbus aria „Magnifica“                          5
#
#                  Herkunft  Wuchs-höhe in Meter  Licht-durchläs-sigkeit   \
# 0               Zuchtform                   NaN                     NaN
# 1    heimisch, Zucht-form                    20                 gering
# 2               Zuchtform                     6                 mittel
# 3               Zuchtform                     6                 mittel
# 4               Zuchtform                     6                 mittel
# ..                     ...                  ...                     ...
# 557             Zuchtform                     9                     NaN
# 558              heimisch                 6 (8)                 mittel
# 559             Zuchtform                     9                     NaN
# 560          Nord-Amerika                   NaN                     NaN
# 561  heimisch, Zucht-form                    15                 gering
#
#                  Lichtbedarf  Winter-härte-zone  KLAM-Stadt   \
# 0    Sonne bis Halbschat-ten                  6b           -
# 1              Halbschat-ten                  5b         2.1
# 2    Sonne bis Halbschat-ten                   5           -
# 3    Sonne bis Halbschat-ten                   5           -
# 4    Sonne bis Halbschat-ten                   5           -
# ..                        ...                ...         ...
# 557                       NaN                  6           -
# 558  Sonne bis Halbschat-ten                  5a         1.1
# 559                       NaN                  6           -
# 560  Sonne bis Halbschat-ten                  6b         3.3
# 561  Sonne bis Halbschat-ten                  5a         1.1
#
#                                           Bemerkungen
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 557                                                NaN
# 558                                                NaN
# 559                                                NaN
# 560  rundliche Krone mit weit ausladenden Seitenäst...
# 561  wie die Art, jedoch kleiner und schmaler, mit ...
#
# [562 rows x 17 columns]

# %%
#Creating a map object and setting the initial view with the latitude and longitude of Düsseldorf
duesseldorf_coords = (51.2277, 6.7735)
map_tree_location = folium.Map(location=duesseldorf_coords, tiles="cartodb positron", zoom_start=12)

# Define a function to determine marker color based on rating
def get_marker_color(klam):
    if KLAM-Stadt== 1.1 or KLAM-Stadt== 1.2 or KLAM-Stadt== 1.3 or KLAM-Stadt== 2.1 or KLAM-Stadt== 2.2 :
        return 'green'
    else:
        return 'red'

for index, row in df_newtrees.iterrows():
    tree_coords1 = (row['latitude'], row['longitude'])
    popup_content1 = f"Tree Type: {row['baumart']}, Planting Year: {row['saison']}"
    marker1 = folium.Marker(location=tree_coords1, popup=popup_content1, icon=folium.Icon(color='green', icon='leaf')) 
    marker1.add_to(map_tree_location)
    
    
# Add markers with colored icons based on rating
for location in locations:
    marker_color = get_marker_color(location['rating'])
    popup_text = f"{location['name']} (Rating: {location['rating']})"
    folium.Marker(
        location=[location['lat'], location['lon']],
        popup=popup_text,
        icon=folium.Icon(color=marker_color)
    ).add_to(m)

# Save the map to an HTML file
m.save("colored_markers_map.html")


map_tree_location
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 13
#      10         return 'red'
#      12 for index, row in df_newtrees.iterrows():
# ---> 13     tree_coords1 = (row['latitude'], row['longitude'])
#      14     popup_content1 = f"Tree Type: {row['baumart']}, Planting Year: {row['saison']}"
#      15     marker1 = folium.Marker(location=tree_coords1, popup=popup_content1, icon=folium.Icon(color='green', icon='leaf'))
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'latitude'
